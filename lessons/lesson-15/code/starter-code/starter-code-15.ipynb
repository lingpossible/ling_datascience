# %% [markdown]
# ## Exploring Rossmann Drug Store Sales Data

# %%
import pandas as pd

data = pd.read_csv('../dataset/rossmann.csv', skipinitialspace=True, low_memory=False)

# %%
data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# Because we are most interested in the `Date` column that contains the date of sales for each store, we will make sure to process that as a `DateTime` type, and make that the index of our dataframe.

# %%
# convert to date value
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data['Year'] = data.index.year
data['Month'] = data.index.month

# %%
store1_data = data[data.Store == 1]

# %% [markdown]
# ### Data Exploration and MINEing

# %% [markdown]
# To compare sales on holidays, we can compare the sales using box-plots, which allows us to compare the distribution of sales on holidays against all other days.  On state holidays, the store is closed (and as a nice sanity check there are 0 sales), and on school holidays the sales are relatively similar.

# %%
import seaborn as sb
# %matplotlib inline

sb.factorplot(
    x='SchoolHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
sb.factorplot(
    x='StateHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
sb.factorplot(
    x='Promo',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
#Add Col to look at the time when the store is open

sb.factorplot(
    col='Open',
    x='Promo',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
# Look at "Day Of Week"
sb.factorplot(
    col='Open',
    x='DayOfWeek',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %% [markdown]
# > Check: See if there is a difference affecting sales on promotion days.

# %%
# TODO

# %% [markdown]
# Lastly, we want to identify larger-scale trends in our data. How did sales change from 2014 to 2015? Were there any particularly interesting outliers in terms of sales or customer visits?

# %%
# Filter to days store 1 was open
store1_open_data = store1_data[store1_data.Open==1]
store1_open_data[['Sales']].plot()

# %%
store1_open_data[['Customers']].plot()

# %%
# Compare the previous chart with a defined time window
pd.rolling_mean(store1_open_data[['Sales']], window=3, center=True).plot()
# Out:
# /Users/linglee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=3,center=True).mean()
#   from ipykernel import kernelapp as app

# %%
# Compare the previous chart with a defined time window. When window size is getting larger, we are comparing the bigger window average, therefore the trend becomes smoother.
pd.rolling_mean(store1_open_data[['Sales']], window=50, center=True).plot()
# Out:
# /Users/linglee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=50,center=True).mean()
#   from ipykernel import kernelapp as app

# %%
# Filter to days store 1 was open
store1_open_2015_data = store1_open_data['2015']
store1_open_2015_data[['Customers']].plot()

# %% [markdown]
# In pandas, we can compute rolling average using the `pd.rolling_mean` or `pd.rolling_median` functions.

# %% [markdown]
# ### Data REFINING Using Time Series Statistics

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# To measure how much the sales are correlated with each other, we want to compute the _autocorrelation_ of the 'Sales' column. In pandas, we do this we with the `autocorr` function:
#
# `autocorr` takes one argument, the `lag` which is how many prio data points should be used to compute the correlation. If we set the `lag` to 1, we compute the correlation between every point and the point directly preceding it. Setting `lag` to 10 computes the correlation between every point and the point 10 days earlier.

# %%
data['Sales'].resample('D').mean().autocorr(lag=1)
# Out:
# -0.025858276006383577

# %%
# Put i to a loop
autoc = []

for i in range(100):
    autoc.append(data['Sales'].resample('D').mean().autocorr(lag=10*i))

df= pd.DataFrame(autoc)
df.plot()

# %% [markdown]
# ### Rolling Averages

# %% [markdown]
# If we want to investigate trends over time in sales, as always, we will start by computing simple aggregates.  What were the mean and median sales for each month and year?
#
# In Pandas, this is performed using the `resample` command, which is very similar to the `groupby` command. It allows us to group over different time intervals.
#
# We can use `data.resample` and provide as arguments:
#     - The level on which to roll-up to, 'D' for day, 'W' for week, 'M' for month, 'A' for year
#     - What aggregation to perform: 'mean', 'median', 'sum', etc.

# %%
data[['Sales']].resample('M').apply(['median', 'mean']).head(100)
# Out:
#              Sales
#             median         mean
# Date
# 2013-01-31  5194.0  5211.555578
# 2013-02-28  5421.5  5494.371397
# 2013-03-31  5844.0  5820.349168
# 2013-04-30  5464.0  5483.749836
# 2013-05-31  5585.0  5364.127383
# 2013-06-30  5428.0  5402.162960
# 2013-07-31  5826.0  6042.062260
# 2013-08-31  5624.0  5729.574049
# 2013-09-30  5294.0  5322.988430
# 2013-10-31  5446.0  5429.258788
# 2013-11-30  5886.5  5864.601614
# 2013-12-31  6566.0  6703.618140
# 2014-01-31  5415.0  5431.875799
# 2014-02-28  5660.0  5731.091512
# 2014-03-31  5500.0  5584.257312
# 2014-04-30  5820.5  5815.993333
# 2014-05-31  5723.0  5632.670534
# 2014-06-30  5735.5  5681.526188
# 2014-07-31  5935.0  5999.403381
# 2014-08-31  5645.0  5649.421252
# 2014-09-30  5739.0  5865.104029
# 2014-10-31  5726.0  5665.564878
# 2014-11-30  6337.5  6179.249661
# 2014-12-31  6915.0  6973.282456
# 2015-01-31  5862.0  5752.747866
# 2015-02-28  5732.0  5710.296541
# 2015-03-31  5910.0  5949.130132
# 2015-04-30  5920.0  5916.857578
# 2015-05-31  5856.0  5472.122002
# 2015-06-30  6042.0  6199.203976
# 2015-07-31  6085.0  6142.705511

# %%
data_store1_monthly = store1_open_data[['Sales']].resample('M').apply('mean')
data_store1_monthly['Sales'].plot()

# %% [markdown]
# While identifying the monthly averages is useful, we often want to compare the sales data of a date to a smaller window. To understand holidays sales, we don't want to compare late December with the entire month, but perhaps with a few days surrounding it. We can do this using rolling averages.
#
# In pandas, we can compute rolling average using the `pd.rolling_mean` or `pd.rolling_median` functions.

# %%
data[['Sales']].resample('D').mean().rolling(window=3, center=True).mean().head()
# Out:
#                   Sales
# Date
# 2013-01-01          NaN
# 2013-01-02  4004.475720
# 2013-01-03  5960.120478
# 2013-01-04  5661.694170
# 2013-01-05  3807.010762

# %% [markdown]
# `rolling_mean` (as well as `rolling_median`) takes these important parameters:
#     - the first is the series to aggregate
#     - `window` is the number of days to include in the average
#     - `center` is whether the window should be centered on the date or use data prior to that date
#     - `freq` is on what level to roll-up the averages to (as used in `resample`). Either `D` for day, `M` for month or `A` for year, etc.

# %% [markdown]
# Instead of plotting the full timeseries, we can plot the rolling mean instead, which smooths random changes in sales as well as removing outliers, helping us identify larger trends.

# %%
data[['Sales']].resample('D').mean().rolling(window=10, center=True).mean().plot()

# %% [markdown]
# ### Pandas Window functions
# Pandas `rolling_mean` and `rolling_median` are only two examples of Pandas window function capabilities. Window functions are operate on a set of N consecutive rows (a window) and produce an output.
#
# In addition to `rolling_mean` and `rolling_median`, there are `rolling_sum`, `rolling_min`, `rolling_max`... and many more.
#
# Another common one is `diff`, which takes the difference over time. `pd.diff` takes one arugment, `periods`, which is how many rows prior to use for the difference.

# %%
data['Sales'].diff(periods=1).head()
# Out:
# Date
# 2015-07-31       NaN
# 2015-07-31     801.0
# 2015-07-31    2250.0
# 2015-07-31    5681.0
# 2015-07-31   -9173.0
# Name: Sales, dtype: float64

# %% [markdown]
# ### Pandas expanding functions
#
# In addition to the set of `rolling_*` functions, Pandas also provides a similar collection of `expanding_*` functions, which, instead of using a window of N values, use all values up until that time.

# %%
# computes the average sales, from the first date _until_ the date specified.
data[['Sales']].resample('D').mean().expanding().mean().head()
# Out:
#                   Sales
# Date
# 2013-01-01    87.284560
# 2013-01-02  3160.157527
# 2013-01-03  4004.475720
# 2013-01-04  4491.911499
# 2013-01-05  4661.079513

# %% [markdown]
# ## Exercises

# %% [markdown]
# > Plot the distribution of sales by month and compare the effect of promotions

# %%
sb.factorplot(  
    col='Open', 
    hue='Promo',  
    x='Month',  
    y='Sales',  
    data=store1_data,   
    kind='box' 
)

# %% [markdown]
# > Are sales more correlated with the prior date, a similar date last year, or a similar date last month?

# %%
average_daily_sales = data[['Sales', 'Open']].resample('D', how='mean')   
average_daily_sales['Sales'].autocorr(lag=1) 
 
average_daily_sales['Sales'].autocorr(lag=30) 
 
average_daily_sales['Sales'].autocorr(lag=365)
# Out:
# /Users/linglee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   if __name__ == '__main__':
# 0.020238529448344551

# %% [markdown]
# > Plot the 15 day rolling mean of customers in the stores

# %%
pd.rolling_mean(data[['Sales']], window=15, freq='D').plot()
# Out:
# /Users/linglee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(freq=D,window=15,center=False).mean()
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-b7c97d3641f4> in <module>()
# ----> 1 pd.rolling_mean(data[['Sales']], window=15, freq='D').plot()
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/stats/moments.pyc in f(arg, window, min_periods, freq, center, **kwargs)
#     474                              center=center,
#     475                              func_kw=func_kw,
# --> 476                              **kwargs)
#     477     return f
#     478
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/stats/moments.pyc in ensure_compat(dispatch, name, arg, func_kw, *args, **kwargs)
#     238                       FutureWarning, stacklevel=3)
#     239
# --> 240     result = getattr(r, name)(*args, **kwds)
#     241
#     242     if is_ndarray:
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in mean(self, *args, **kwargs)
#    1110     def mean(self, *args, **kwargs):
#    1111         nv.validate_rolling_func('mean', args, kwargs)
# -> 1112         return super(Rolling, self).mean(*args, **kwargs)
#    1113
#    1114     @Substitution(name='rolling')
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in mean(self, *args, **kwargs)
#     839     def mean(self, *args, **kwargs):
#     840         nv.validate_window_func('mean', args, kwargs)
# --> 841         return self._apply('roll_mean', 'mean', **kwargs)
#     842
#     843     _shared_docs['median'] = dedent("""
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in _apply(self, func, name, window, center, check_minp, how, **kwargs)
#     693             check_minp = _use_window
#     694
# --> 695         blocks, obj, index = self._create_blocks(how=how)
#     696         index, indexi = self._get_index(index=index)
#     697         results = []
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in _create_blocks(self, how)
#     121         """ split data into blocks & return conformed data """
#     122
# --> 123         obj, index = self._convert_freq(how)
#     124         if index is not None:
#     125             index = self._on
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/window.pyc in _convert_freq(self, how)
#     114                               stacklevel=6)
#     115
# --> 116             obj = obj.resample(self.freq).aggregate(how or 'asfreq')
#     117
#     118         return obj, index
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/tseries/resample.pyc in aggregate(self, arg, *args, **kwargs)
#     318
#     319         self._set_binner()
# --> 320         result, how = self._aggregate(arg, *args, **kwargs)
#     321         if result is None:
#     322             return self._groupby_and_aggregate(arg,
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in _aggregate(self, arg, *args, **kwargs)
#     430         _level = kwargs.pop('_level', None)
#     431         if isinstance(arg, compat.string_types):
# --> 432             return getattr(self, arg)(*args, **kwargs), None
#     433
#     434         if isinstance(arg, dict):
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/tseries/resample.pyc in asfreq(self)
#     505         essentially a reindex with (no filling)
#     506         """
# --> 507         return self._upsample('asfreq')
#     508
#     509     def std(self, ddof=1, *args, **kwargs):
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/tseries/resample.pyc in _upsample(self, method, limit)
#     737         else:
#     738             result = obj.reindex(res_index, method=method,
# --> 739                                  limit=limit)
#     740
#     741         return self._wrap_result(result)
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in reindex(self, index, columns, **kwargs)
#    2819     def reindex(self, index=None, columns=None, **kwargs):
#    2820         return super(DataFrame, self).reindex(index=index, columns=columns,
# -> 2821                                               **kwargs)
#    2822
#    2823     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in reindex(self, *args, **kwargs)
#    2257         # perform the reindex on the axes
#    2258         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2259                                   fill_value, copy).__finalize__(self)
#    2260
#    2261     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2765         if index is not None:
#    2766             frame = frame._reindex_index(index, method, copy, level,
# -> 2767                                          fill_value, limit, tolerance)
#    2768
#    2769         return frame
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    2776         return self._reindex_with_indexers({0: [new_index, indexer]},
#    2777                                            copy=copy, fill_value=fill_value,
# -> 2778                                            allow_dups=False)
#    2779
#    2780     def _reindex_columns(self, new_columns, copy, level, fill_value=NA,
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    2369                                                 fill_value=fill_value,
#    2370                                                 allow_dups=allow_dups,
# -> 2371                                                 copy=copy)
#    2372
#    2373         if copy and new_data is self._data:
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3837         # some axes don't allow reindexing with dups
#    3838         if not allow_dups:
# -> 3839             self.axes[axis]._can_reindex(indexer)
#    3840
#    3841         if axis >= self.ndim:
#
# /Users/linglee/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in _can_reindex(self, indexer)
#    2492         # trying to reindex on an axis with duplicates
#    2493         if not self.is_unique and len(indexer):
# -> 2494             raise ValueError("cannot reindex from a duplicate axis")
#    2495
#    2496     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %% [markdown]
# > Identify the date with largest drop in sales from the same date in the previous month

# %%
average_daily_sales = data[['Sales', 'Open']].resample('D', how='mean')  average_daily_sales['DiffVsLastWeek'] = average_daily_sales[['Sales']].diff(periods=7) 
 
average_daily_sales.sort(['DiffVsLastWeek']).head
# Out:
#   File "<ipython-input-63-112c86ff9daa>", line 1
#     average_daily_sales = data[['Sales', 'Open']].resample('D', how='mean')  average_daily_sales['DiffVsLastWeek'] = average_daily_sales[['Sales']].diff(periods=7)
#                                                                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# > Compute the total sales up until Dec. 2014

# %% [markdown]
# > When were the largest differences between 15-day moving/rolling averages?
# > HINT: Using `rolling_mean` and `diff`
